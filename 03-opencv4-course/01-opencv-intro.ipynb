# %% [markdown]
# # Introduction

# %% [markdown]
# ### Neural Network (Input, Hidden, Output Layers)
# You have the input layer, which has an image with the number four on it, and the final output prediction showing that the number four has been detected.
#
# The layers in between are known as hidden layers, and each layer has weights and biases that can be modified. A deep learning network is one where you have more than one hidden layer.
#
# ### What's actually happening in these layers?
# Each layer is learning certain characteristics of the image. This could be the edges or corners or textures. Now, when you feed the deep learning network several different images of a handwritten number four and tell it that these are all fours, the network gets good at determining when you've written a hand number four by learning this. When you first pass an image of a number four, the weights of the different layers are random. This means the final prediction from the deep learning network is unlikely to be a number four.
#
# There needs to be some way for the network to compare what the predicted value is and what the actual values are. This is done using a __loss function__, and here, in order to get the predicted values closer to the actual values, we need to reduce the loss function.
#
# To do this, we need some sort of feedback mechanism, so we compare the predicted output with the actual one, and then, modify the weights of each of the layers starting from the final layer and working our way back. This is the job of the optimizer using an algorithm called __backpropagation__.

# %% [markdown]
# ------

# %% [markdown]
# ## What is OpenCV?

# %% [markdown]
# OpenCV is an open source computer vision and machine learning software library. It's probably the most popular computer vision software out there. The library has more than 2,500 optimized algorithms, which includes classic and state-of-the-art computer vision and machine learning algorithms. These algorithms can be used to detect and recognize faces, identify objects, classify human actions in videos, track camera movements and moving objects amongst many others.
#
#  We'll be using OpenCV's deep neural network or DNN module in this course

# %% [markdown]
# ---------

# %% [markdown]
# ### Inference
#
# OpenCV's deep learning module is known as DNN. It's important to understand that the DNN model is not a full-fledged deep learning framework. We cannot train any deep learning network. There is no backpropagation and so no learning that takes place. So we can take an input data, pass it through a previously trained deep neural network model and output the result. This is known as inference.
#
# In deep learning terminology, this means that only a forward pass takes place.
#
# Now if you've only got a forward pass this makes the code more simple. The installation and assembly of the deep learning network is quicker and is fast enough on CPUs.

# %% [markdown]
# --------

# %% [markdown]
# ## Advantages of OpenCV

# %% [markdown]
# ### OpenCV is framework-independent
# - It has not framework-specific limitations
#
# ### Models are represented internally in OpenCV
# - Code can be optimized
#
# ### OpenCV has its own deep learning implementation
# - External dependencies are kept to a minimum

# %% [markdown]
# ### Inference Engine Example

# %% [markdown]
# A simple inference engine will simply pass the input data through the network and output the result.
#
#  However, there are a lot of optimizations that can be performed that make the inference speed fast. For example, an efficient inference engine could do things like __prune part of the neural network__ that isn't activated or combine multiple layers into a single computational step.

# %% [markdown]
# ### OpenCV Accuracy vs. ResNet50
#
#  OpenCV has published several test results indicating that there's absolutely no difference in accuracy between say using the DNN module and ResNet 50 and the actual results from ResNet 50. This means that you'll get the same results regardless of whether you use OpenCV's DNN module or the original architecture.

# %% [markdown]
# -------

# %% [markdown]
# ## Understanding Images

# %% [markdown]
#  A grayscale camera records the intensity of reflected light. A color camera records the light reflected at three points of the visible spectrum: red, green, and blue. Color is the way the human eye perceives a mixture of lights of different wavelengths.

# %%
from PIL import Image
Image.open('Images/01-color.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1091x503 at 0x1CC15E842E8>

# %% [markdown]
# The __RGB color model__ gets its name from the three primary colors: red, green, and blue. Now, what's a little confusing is that in OpenCV we use the BGR format, so that's blue, green, and red, rather than RGB. The reason for this is when OpenCV first started off, the BGR color format was popular among camera manufacturers and software providers.

# %%
Image.open('Images/02-bgr.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=593x499 at 0x1CC1861B6A0>

# %% [markdown]
# ----

# %% [markdown]
# ## Viewing Images in CV2
#
#     img = cv.imread('pic.jpg, cv.IMREAD_COLOR) for color and img = cv.imread('pic.jpg', cv.IMREAD_GRAYSCALE) # Explicit

# %%
import numpy as np
import cv2

# %%
# Read image
img = cv2.imread('Images/devon.jpg') # numpy array image
img
# Out:
# array([[[209, 169, 144],
#         [209, 169, 144],
#         [210, 170, 145],
#         ...,
#         [229, 181, 157],
#         [227, 179, 155],
#         [225, 177, 153]],
#
#        [[212, 172, 147],
#         [212, 172, 147],
#         [212, 172, 147],
#         ...,
#         [228, 180, 156],
#         [227, 179, 155],
#         [227, 179, 155]],
#
#        [[213, 173, 148],
#         [213, 173, 148],
#         [213, 173, 148],
#         ...,
#         [226, 178, 154],
#         [226, 178, 154],
#         [227, 179, 155]],
#
#        ...,
#
#        [[ 15,  70,  55],
#         [ 18,  75,  60],
#         [ 17,  79,  61],
#         ...,
#         [ 58, 121, 105],
#         [ 89, 139, 137],
#         [109, 154, 157]],
#
#        [[ 18,  73,  58],
#         [ 22,  79,  64],
#         [ 23,  85,  69],
#         ...,
#         [ 52, 117, 101],
#         [ 95, 145, 143],
#         [139, 184, 187]],
#
#        [[ 37,  92,  77],
#         [ 42,  99,  84],
#         [ 30,  92,  76],
# ...

# %% [markdown]
# ### Shape & Type

# %%
img.shape # 360x480x3 (BGR) colored image; 360 rows, 480 columns, 3 channels
# Out:
# (360, 480, 3)

# %%
print(type(img)) # <class 'numpy.ndarray'>
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Display the image

# %%
cv2.imshow('Image', img)
cv2.waitKey(0) # execution is paused until a key is pressed; wait 0 zeros before showing image
cv2.destroyAllWindows() # destroyed all windows that have been created

# %% [markdown]
# ### Display blue channels
# Each color channel has different values, or intensities. So when you see values closer to zero, this means that none of that color appears in that pixel.
#
# Now let's say we want to display the blue channel. Then we want all of the rows and all of the columns, which we represent as a colon in numpy, and the first array is given by zero. So, b is img, all of the rows, all of the columns, and because we have it in the bgr format we want the first one, which is a zero.

# %%
# Read image
img = cv2.imread('Images/devon.jpg') # numpy array image
img

# Get all rows and columns from img
b = img[:, :, 0] # BGR so B = 0
b # values of the numpy array

# %% [markdown]
# So this picture of the skies, house, and landscape would show high values that are closer to 255 (highest level) at the top of the array vs the bottom which is evident as shown above in b.

# %% [markdown]
# ### Get all colors

# %%
# Read image
img = cv2.imread('Images/devon.jpg') # numpy array image
img

# Blue; get all rows and columns from img for the first element
b = img[:, :, 0] # BGR so B = 0

# Green
g = img[:, :, 1] # BGR so B = 0

# Red
r = img[:, :, 2] # BGR so B = 0

# Print values of blue
print(b) # values of the numpy array

# Display the image
cv2.imshow('Blue', b)
cv2.imshow('Green', g)
cv2.imshow('Red', r)
cv2.imshow('Image', img)
cv2.waitKey(0) # execution is paused until a key is pressed; wait 0 zeros before showing image
cv2.destroyAllWindows() # destroyed all windows that have been created

# %%
Image.open('Images/03-landscape-bgr.png')

# %% [markdown]
# ### Intensity / GrayScale Channels
# So each of the channels are essentially three intensity channels, or three grayscale channels representing the colors. Wherever we have a large contribution for a particular color, the color for that section of the image is lighter in the grayscale image.
#
# So you can see for the blue channel, the sky is lighter than in the red and green. Now this makes sense, because we have a higher contribution of blue here, and the code for white is 255, 255, 255. For the green channel, the grass is lighter than in the red and blue channels. And where you have the house roof, you can see that this is lighter for the red channel compared to the other two channels.

# %%
Image.open('Images/03-landscape-bgr.png')

# %% [markdown]
# ---------

# %% [markdown]
# ## Viewing Videos in OpenCV
#
# What is 0xFF?
#
# 0xFF is a hexadecimal constant which is 11111111 in binary. By using bitwise AND (&) with this constant, it leaves only the last 8 bits of the original (in this case, whatever cv2.waitKey(0) is).

# %%
import numpy as np
import cv2

# Create a video capture object and read in the input file to check to see that it can open the file
cap = cv2.VideoCapture('Videos/shore.mov')

# Webcam input instead
# cap = cv2.VideoCapture(0)

# Make sure we can open the video file
if cap.isOpened() == False:
    print('Cannot open file or video stream')
    
# Read and display video frames until either the video is completed or the user quits by typing an escape key so while true
while True:
    
    # Call that return and frame and return true to see the frame
    ret, frame = cap.read() # returns 2 parameters
    
    # If true, show frame
    if ret == True:
        cv2.imshow('Frame', frame)
        
        # Pass a number greater than zero for videos; OpenCV suggests 25 milliseconds
        if cv2.waitKey(25) & 0xFF == 27:
            break
    else:
        break

# Once we're done, release the video and remove windows        
cap.release()
cv2.destroyAllWindows()
